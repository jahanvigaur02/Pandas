# %% [markdown]
# # <u>  PANDAS

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\jkash\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\jkash\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\jkash\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
mydata=pd.read_excel(r"C:\---janvi---\DataSets-master\Population_Summary.xlsx")

# %%
mydata
# Out:
#    Rank           State_UT  Population  Rulal  Urban  Share  Growth  \
# 0     1      Uttar Pradesh   199812341  77.73  22.27  16.50   20.23
# 1     2        Maharashtra   112374333  54.78  45.22   9.28   15.99
# 2     3              Bihar   104099452  88.71  11.29   8.60   25.42
# 3     4        West Bengal    91276115  68.13  31.87   7.54   13.84
# 4     5     Andhra Pradesh    84580777  66.64  33.36   6.99   10.98
# 5     6     Madhya Pradesh    72626809  72.37  27.63   6.00   20.35
# 6     7         Tamil Nadu    72147030  51.60  48.40   5.96   15.61
# 7     8          Rajasthan    68548437  75.13  24.87   5.66   21.31
# 8     9          Karnataka    61095297  61.33  38.67   5.05   15.60
# 9    10            Gujarat    60439692  57.40  42.60   4.99   19.28
# 10   11             Odisha    41974218  83.31  16.69   3.47   14.05
# 11   12             Kerala    33406061  52.30  47.70   2.76    4.91
# 12   13          Jharkhand    32988134  75.95  24.05   2.72   22.42
# ...

# %%
mydata.shape
# Out:
# (35, 9)

# %%
mydata.head(10)
# Out:
#   Rank        State_UT  Population  Rulal  Urban  Share  Growth      Country  \
# 0    1   Uttar Pradesh   199812341  77.73  22.27  16.50   20.23       Brazil
# 1    2     Maharashtra   112374333  54.78  45.22   9.28   15.99       Mexico
# 2    3           Bihar   104099452  88.71  11.29   8.60   25.42  Philippines
# 3    4     West Bengal    91276115  68.13  31.87   7.54   13.84     Viet Nam
# 4    5  Andhra Pradesh    84580777  66.64  33.36   6.99   10.98        Egypt
# 5    6  Madhya Pradesh    72626809  72.37  27.63   6.00   20.35       Turkey
# 6    7      Tamil Nadu    72147030  51.60  48.40   5.96   15.61       Turkey
# 7    8       Rajasthan    68548437  75.13  24.87   5.66   21.31        Congo
# 8    9       Karnataka    61095297  61.33  38.67   5.05   15.60        Italy
# 9   10         Gujarat    60439692  57.40  42.60   4.99   19.28        Italy
#
#    World_Rank
# 0           5
# 1          11
# 2          12
# 3          14
# 4          15
# 5          18
# ...

# %%
mydata.sample(5)
# Out:
#    Rank      State_UT  Population  Rulal  Urban  Share  Growth      Country  \
# 25   25           Goa     1458545  37.83  62.17   0.12    8.23        Gabon
# 13   14         Assam    31205576  85.90  14.10   2.58   17.07  Afghanistan
# 21   21       Tripura     3673917  73.83  26.17   0.30   14.84         Oman
# 32  UT4  D.& N.Haveli      343709  53.28  46.72   0.03   55.88       Belize
# 30   28        Sikkim      610577  74.85  25.15   0.05   12.89   Montenegro
#
#     World_Rank
# 25         151
# 13          40
# 21         130
# 32         179
# 30         166

# %%
mydata.describe()
# Out:
#          Population      Rulal      Urban      Share     Growth  World_Rank
# count  3.500000e+01  35.000000  35.000000  35.000000  35.000000   35.000000
# mean   3.459586e+07  61.160571  38.839429   2.857714  19.299143   86.485714
# std    4.445234e+07  22.219493  22.219493   3.671310  11.125100   65.736270
# min    6.447300e+04   2.500000  10.030000   0.010000  -0.580000    5.000000
# 25%    1.421136e+06  52.790000  24.460000   0.115000  13.865000   23.000000
# 50%    1.678794e+07  68.130000  31.870000   1.390000  18.810000   64.000000
# 75%    6.076749e+07  75.540000  47.210000   5.020000  23.045000  151.500000
# max    1.998123e+08  89.970000  97.500000  16.500000  55.880000  205.000000

# %%
mydata.dtypes
# Out:
# Rank           object
# State_UT       object
# Population      int64
# Rulal         float64
# Urban         float64
# Share         float64
# Growth        float64
# Country        object
# World_Rank      int64
# dtype: object

# %%
pop=mydata["Population"]
type(pop)
# Out:
# pandas.core.series.Series

# %%
mydata[mydata["Population"]==mydata["Population"].min()]
# Out:
#    Rank     State_UT  Population  Rulal  Urban  Share  Growth  Country  \
# 34  UT6  Lakshadweep       64473  21.93  78.07   0.01     6.3  Bermuda
#
#     World_Rank
# 34         205

# %%
mydata["Average"]=mydata["Population"]/(mydata["Population"].sum()*100)

# %%
mydata.head(5)
# Out:
#   Rank        State_UT  Population  Rulal  Urban  Share  Growth      Country  \
# 0    1   Uttar Pradesh   199812341  77.73  22.27  16.50   20.23       Brazil
# 1    2     Maharashtra   112374333  54.78  45.22   9.28   15.99       Mexico
# 2    3           Bihar   104099452  88.71  11.29   8.60   25.42  Philippines
# 3    4     West Bengal    91276115  68.13  31.87   7.54   13.84     Viet Nam
# 4    5  Andhra Pradesh    84580777  66.64  33.36   6.99   10.98        Egypt
#
#    World_Rank   Average
# 0           5  0.001650
# 1          11  0.000928
# 2          12  0.000860
# 3          14  0.000754
# 4          15  0.000699

# %%
mydata.sort_values(by=['Population'],axis=0,ascending=False,kind='quicksort').head(5)
# Out:
#   Rank        State_UT  Population  Rulal  Urban  Share  Growth      Country  \
# 0    1   Uttar Pradesh   199812341  77.73  22.27  16.50   20.23       Brazil
# 1    2     Maharashtra   112374333  54.78  45.22   9.28   15.99       Mexico
# 2    3           Bihar   104099452  88.71  11.29   8.60   25.42  Philippines
# 3    4     West Bengal    91276115  68.13  31.87   7.54   13.84     Viet Nam
# 4    5  Andhra Pradesh    84580777  66.64  33.36   6.99   10.98        Egypt
#
#    World_Rank   Average
# 0           5  0.001650
# 1          11  0.000928
# 2          12  0.000860
# 3          14  0.000754
# 4          15  0.000699

# %%
mydata["Average"]>.10
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# Name: Average, dtype: bool

# %%
mydata.drop(["Rank"],axis=1,inplace=True)

# %%
mydata
# Out:
#              State_UT  Population  Rulal  Urban  Share  Growth  \
# 0       Uttar Pradesh   199812341  77.73  22.27  16.50   20.23
# 1         Maharashtra   112374333  54.78  45.22   9.28   15.99
# 2               Bihar   104099452  88.71  11.29   8.60   25.42
# 3         West Bengal    91276115  68.13  31.87   7.54   13.84
# 4      Andhra Pradesh    84580777  66.64  33.36   6.99   10.98
# 5      Madhya Pradesh    72626809  72.37  27.63   6.00   20.35
# 6          Tamil Nadu    72147030  51.60  48.40   5.96   15.61
# 7           Rajasthan    68548437  75.13  24.87   5.66   21.31
# 8           Karnataka    61095297  61.33  38.67   5.05   15.60
# 9             Gujarat    60439692  57.40  42.60   4.99   19.28
# 10             Odisha    41974218  83.31  16.69   3.47   14.05
# 11             Kerala    33406061  52.30  47.70   2.76    4.91
# 12          Jharkhand    32988134  75.95  24.05   2.72   22.42
# 13              Assam    31205576  85.90  14.10   2.58   17.07
# ...

# %%
mydata.rename(columns={"Population":"POP"})
# Out:
#              State_UT        POP  Rulal  Urban  Share  Growth  \
# 0       Uttar Pradesh  199812341  77.73  22.27  16.50   20.23
# 1         Maharashtra  112374333  54.78  45.22   9.28   15.99
# 2               Bihar  104099452  88.71  11.29   8.60   25.42
# 3         West Bengal   91276115  68.13  31.87   7.54   13.84
# 4      Andhra Pradesh   84580777  66.64  33.36   6.99   10.98
# 5      Madhya Pradesh   72626809  72.37  27.63   6.00   20.35
# 6          Tamil Nadu   72147030  51.60  48.40   5.96   15.61
# 7           Rajasthan   68548437  75.13  24.87   5.66   21.31
# 8           Karnataka   61095297  61.33  38.67   5.05   15.60
# 9             Gujarat   60439692  57.40  42.60   4.99   19.28
# 10             Odisha   41974218  83.31  16.69   3.47   14.05
# 11             Kerala   33406061  52.30  47.70   2.76    4.91
# 12          Jharkhand   32988134  75.95  24.05   2.72   22.42
# 13              Assam   31205576  85.90  14.10   2.58   17.07
# ...

# %% [markdown]
# ### BMI_DATASET

# %%
bmi_data=pd.read_csv(r"C:\Users\jkash\Downloads\DataSets-master\DataSets-master\Bmi_male_female.csv")

# %%
bmi_data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
#bmi_data.describe

# %%
#value_counts: used for discret value and only apllicable in pandas series
bmi_data.Gender.value_counts()
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
bmi_data.groupby(["Index","Gender"]).count()
# Out:
#               Height  Weight
# Index Gender
# 0     Female       7       7
#       Male         6       6
# 1     Female       7       7
#       Male        15      15
# 2     Female      41      41
#       Male        28      28
# 3     Female      36      36
#       Male        32      32
# 4     Female      71      71
#       Male        59      59
# 5     Female      93      93
#       Male       105     105

# %%
bmi_data.groupby("Gender")["Index"].nunique().to_frame()
# Out:
#         Index
# Gender
# Female      6
# Male        6

# %%
rr=bmi_data["Gender"].value_counts()
rr
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
k=rr.keys().tolist()
v=rr.values.tolist()

# %%
plt.bar(k,v,color="Green")
plt.xlabel("Genders",color="blue",size=25)
plt.ylabel("counts",color="blue",size=25)
plt.show()

# %%
import seaborn as sb
sb.countplot(x="Gender",data=bmi_data,hue="Index")
plt.show()
